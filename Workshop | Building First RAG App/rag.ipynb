# %%
# %load_ext autoreload
# %autoreload 2

from dotenv import load_dotenv
load_dotenv()

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from anthropic import Anthropic

documents = load_faq_data()
index = build_index(documents)

anthropic_client = Anthropic()

assistant = RAGBase(
    index=index,
    llm_client=anthropic_client,
)

answer = assistant.rag('I just discovered the course. Can I join now?')
print(answer)
# Out:
# Yes, you can join now!
#
# However, there's an important detail regarding certificates: **if you want to receive a certificate, you need to submit your project while submissions are still being accepted.** This means you should act promptly to complete the course work and submit your project within the submission deadline.
#
# Also note that certificates are only awarded when you complete the course with a "live" cohort, not in self-paced mode. The next course offering is scheduled for **Summer 2025**.
#
# You can start learning and submitting homework right away without needing to wait for any confirmation email.

# %% [markdown]
# ##### considerations

# %% [markdown]
# minsearch is not really effective 'cause it does not allow to memorize the data; it is not a persistant search, it is in memory
#
# for rag application a persistant search is needed, for example elasticSearch

# %% [markdown]
# ###### persistant search
